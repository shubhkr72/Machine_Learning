# %% [markdown]
# # Panda Data analysis

# %%
import pandas as pd

# %%
#2 main dataType
# s in series is in capita
series=pd.Series(["toyota","bmw","maruti","xone","nano"])

# %%
series
# Out:
# 0    toyota
# 1       bmw
# 2    maruti
# 3      xone
# 4      nano
# dtype: object

# %%
#series =1-dimensional

# %%
colours=pd.Series(["red","black","pink","blue","green","yellow"])
colours
# Out:
# 0       red
# 1     black
# 2      pink
# 3      blue
# 4     green
# 5    yellow
# dtype: object

# %%
#dataframe is 2-Dimentional
#comon data type
car_data=pd.DataFrame({"car_make":series,"colour":colours})
car_data
# Out:
#   car_make  colour
# 0   toyota     red
# 1      bmw   black
# 2   maruti    pink
# 3     xone    blue
# 4     nano   green
# 5      NaN  yellow

# %%
#import data file in csv
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# axis 0=row
#axis 1=column
#import image file

# %%
#exporting a dataframe
car_sales.to_csv("exported-car-sales.csv",index=False)
# car_sales.to_excel("exported-car-sales-in-excel.xlsx")
#to convert in excel install openpyxl

# %%
#extracting data from url raw data
car_git_data=pd.read_csv("https://raw.githubusercontent.com/shubhkr72/zero-to-mastery-ml/master/data/car-sales.csv")

# %%
car_git_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # 006 Describing data with pandas

# %%
#Attibute dont have ()
#functions have () to pass arguments
# a.to_csv()
car_sales.dtypes
#gives type of values
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#describe only int type
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
#idk why it is giving error
car_sales.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #idk why it is giving error
# ----> 2 car_sales.mean()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %%
car_prices=pd.Series([2000,5000,7000,4000,2500])
car_prices.mean()

# %%
car_sales.sum()

# %%
# we can select columns to describe about
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Doors"].mode()
# Out:
# 0    4
# Name: Doors, dtype: int64

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # 007 Selecting and Viewing Data with Pandas

# %%
#gives 5 rows only we can give arguments
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
#Can give argumrnts
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#  .loc=location  .iloc
animals=pd.Series(["Cat","Ox","Bird","Peacock"],index=[1,7,3,9])
animals
# Out:
# 1        Cat
# 7         Ox
# 3       Bird
# 9    Peacock
# dtype: object

# %%
animals.loc[3]
#give indexed
#give coresponding data
# Out:
# 'Bird'

# %%
# iloc refers to position not location
animals.iloc[3]
# Out:
# 'Peacock'

# %%
#slicing list
#gives 3
animals.iloc[:3]
# Out:
# 1     Cat
# 7      Ox
# 3    Bird
# dtype: object

# %%
car_sales["Doors"]
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
car_sales[car_sales["Make"]=="Toyota"]
#gives all rows with toyota as make
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
#gives value greater than 100000
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # 008 Selecting and Viewing Data with Pandas Part 2

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
#crosstab counting in matrix form
#for comparing two columns
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Group by
car_sales.groupby(["Make"]).mean()
#idk why it is giving error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
car_sales["Doors"].plot()

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
#changing object to int price
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]', '',regex=True)
##
##why it is giving error
##
car_sales
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\shubh\AppData\Local\Temp\ipykernel_14232\2487776032.py:2: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]', '',regex=True)
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# ...

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.upper()
# it doesn't change in original data
#have to reassign to make changes in original data set
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"]=car_sales["Make"].str.upper()
#it changes in original data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
#dealing with missing data

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].plot()
# Out:
# <Axes: >

# %%
# car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"]).mean()

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna({car_sales_missing["Odometer"]:NaN}.mean())
#ye purana version ka hai
# ab change hoga assignment ho gya to
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Doors"]=car_sales_missing["Doors"].fillna(car_sales_missing["Doors"].mean())
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
updated=car_sales_missing.dropna()
updated
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
updated.to_csv("car_sales_missing_updated_data.csv")

# %% [markdown]
# # manipulating_2 010

# %%
#columns from series
#adding new colunm
#very right side create
seat_column=pd.Series([2,4,7,5,6,3,2,2,4,53,2,2,76])
car_sales["Seats"]=seat_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  TOYOTA  White         150043      4   400000      2
# 1   HONDA    Red          87899      4   500000      4
# 2  TOYOTA   Blue          32549      3   700000      7
# 3     BMW  Black          11179      5  2200000      5
# 4  NISSAN  White         213095      4   350000      6
# 5  TOYOTA  Green          99213      4   450000      3
# 6   HONDA   Blue          45698      4   750000      2
# 7   HONDA   Blue          54738      4   700000      2
# 8  TOYOTA  White          60000      4   625000      4
# 9  NISSAN  White          31600      4   970000     53

# %%
#column from python list
fuel_economy=[1,4.5,3.7,3.6,8.0,7.6,5.5,4.6,7,8]
car_sales["Fuel_eco"]=fuel_economy
car_sales
#size of list must be equal to size of indexes 
#not in case of series 
# series add NaN but list not list give error
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# 9  NISSAN  White          31600      4   970000     53       8.0

# %%
# creating column based in 2 columns
car_sales["Total fuel used{L}"]=(car_sales["Odometer (KM)"]/100)*car_sales["Fuel_eco"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# 9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}
# 0         1500.430            1500.430
# 1         3955.455            3955.455
# 2         1204.313            1204.313
# 3          402.444             402.444
# 4        17047.600           17047.600
# ...

# %%
#creating a column from single value
car_sales["NumberOfWheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# 9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 0         1500.430            1500.430               4
# 1         3955.455            3955.455               4
# 2         1204.313            1204.313               4
# ...

# %%
car_sales["RoadSafety"]=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# 9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels  RoadSafety
# 0         1500.430            1500.430               4        True
# 1         3955.455            3955.455               4        True
# ...

# %%
car_sales=car_sales.drop("RoadSafety",axis=1)
car_sales
# axis=1 means column
#axis=0 means row
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1   HONDA    Red          87899      4   500000      4       4.5
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 5  TOYOTA  Green          99213      4   450000      3       7.6
# 6   HONDA   Blue          45698      4   750000      2       5.5
# 7   HONDA   Blue          54738      4   700000      2       4.6
# 8  TOYOTA  White          60000      4   625000      4       7.0
# 9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 0         1500.430            1500.430               4
# 1         3955.455            3955.455               4
# 2         1204.313            1204.313               4
# ...

# %%
# car_sales=car_sales.drop(["BMW"])
# car_sales
# delete from row giving error

# %%
from PIL import Image
Image.open("004 pandas-anatomy-of-a-dataframe.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1986x1104>

# %% [markdown]
# # manipulating -->3

# %%
#sample shuffle index
#for training validation testing
#randomising data

# %%
car_sales.sample(frac=0.5)
#farc means portion of data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 2  TOYOTA   Blue          32549      3   700000      7       3.7
# 3     BMW  Black          11179      5  2200000      5       3.6
# 4  NISSAN  White         213095      4   350000      6       8.0
# 9  NISSAN  White          31600      4   970000     53       8.0
# 7   HONDA   Blue          54738      4   700000      2       4.6
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 2         1204.313            1204.313               4
# 3          402.444             402.444               4
# 4        17047.600           17047.600               4
# 9         2528.000            2528.000               4
# 7         2517.948            2517.948               4

# %%
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 9  NISSAN  White          31600      4   970000     53       8.0
# 3     BMW  Black          11179      5  2200000      5       3.6
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 9         2528.000            2528.000               4
# 3          402.444             402.444               4

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0      0  TOYOTA  White         150043      4   400000      2       1.0
# 1      5  TOYOTA  Green          99213      4   450000      3       7.6
# 2      8  TOYOTA  White          60000      4   625000      4       7.0
# 3      4  NISSAN  White         213095      4   350000      6       8.0
# 4      2  TOYOTA   Blue          32549      3   700000      7       3.7
# 5      1   HONDA    Red          87899      4   500000      4       4.5
# 6      7   HONDA   Blue          54738      4   700000      2       4.6
# 7      3     BMW  Black          11179      5  2200000      5       3.6
# 8      6   HONDA   Blue          45698      4   750000      2       5.5
# 9      9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 0         1500.430            1500.430               4
# 1         7540.188            7540.188               4
# ...

# %%
car_sales_shuffled.reset_index(drop=True)
#use drop to remove previous indexing
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White         150043      4   400000      2       1.0
# 1  TOYOTA  Green          99213      4   450000      3       7.6
# 2  TOYOTA  White          60000      4   625000      4       7.0
# 3  NISSAN  White         213095      4   350000      6       8.0
# 4  TOYOTA   Blue          32549      3   700000      7       3.7
# 5   HONDA    Red          87899      4   500000      4       4.5
# 6   HONDA   Blue          54738      4   700000      2       4.6
# 7     BMW  Black          11179      5  2200000      5       3.6
# 8   HONDA   Blue          45698      4   750000      2       5.5
# 9  NISSAN  White          31600      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 0         1500.430            1500.430               4
# 1         7540.188            7540.188               4
# 2         4200.000            4200.000               4
# ...

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
#lambda is for anonomys function declaration

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_eco  \
# 0  TOYOTA  White   58610.546875      4   400000      2       1.0
# 1   HONDA    Red   34335.546875      4   500000      4       4.5
# 2  TOYOTA   Blue   12714.453125      3   700000      7       3.7
# 3     BMW  Black    4366.796875      5  2200000      5       3.6
# 4  NISSAN  White   83240.234375      4   350000      6       8.0
# 5  TOYOTA  Green   38755.078125      4   450000      3       7.6
# 6   HONDA   Blue   17850.781250      4   750000      2       5.5
# 7   HONDA   Blue   21382.031250      4   700000      2       4.6
# 8  TOYOTA  White   23437.500000      4   625000      4       7.0
# 9  NISSAN  White   12343.750000      4   970000     53       8.0
#
#    Total fuel used  Total fuel used{L}  NumberOfWheels
# 0         1500.430            1500.430               4
# 1         3955.455            3955.455               4
# 2         1204.313            1204.313               4
# ...
